# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriaIvanova/metall_surface/blob/main/Faster_rcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive  # подключение к диску где содержится архив с датасетом
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Dip.zip"  # распаковка архива с датасетом
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/Types.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils.h
#    creating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/auto_gil.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/byte_order.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/cpp_stacktraces.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/cuda_enabled.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/cuda_lazy_init.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/disable_torch_function.h
#   inflating: Dip/venv/Lib/site-packages/torch/include/torch/csrc/utils/init.h
# ...

# %%
# %cd Dip
# Out:
# /content/Dip

# %%
# !python train.py --model fasterrcnn_resnet50_fpn --epochs 40 --config data_configs/dataset.yaml --no-mosaic --batch-size 16
# Out:
# data/dataset/train/crazing_172.xml not found...
# Removing crazing_172.jpg image
# data/dataset/train/inclusion_121.xml not found...
# Removing inclusion_121.jpg image
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of training samples: 1286
# Number of validation samples: 322
#
# Building model from scratch...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100% 160M/160M [00:00<00:00, 236MB/s]
# FasterRCNN(
# ...
